# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# Midtown is a busy commercial area and a vibrant arts hub. The High Museum of Art shows world-renowned works in a striking modern building, while Margaret Mitchell House offers tours of the former home of the “Gone With the Wind” author. Peachtree Street is a hotspot for comedy, bars and big-name shops, with eating options ranging from street food to fine dining. Large, leafy Piedmont Park offers walking trails.
#
# Problem
# * I will be trying to open a new coffee Store in midtown Atlanta.
# * I will like to know how many Coffee stores are already in the area.
# * How spaced out are the stores. and how much foot traffic is in the area and what time will be the best time to be open

# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# Midtown Atlanta has a large and ethnically diverse metropolis demographic Area. With it diverse areal comes with lots of activities and different kinds of food.

# %% [markdown]
# For this project we will be using the data below

# %% [markdown]
# ##### This data contains are the Neighbourhoods with latitude and longitude in Atlanta
# * https://cocl.us/atlanta_dataset
# ##### All the Coffee shops in Atlanta
# * Foursquare API
# ##### GeoSpace data
# * https://data.cityofatlanta.us/City-Government
# ##### The listing of Neighborhoods in Atlanta from Wikipedia page
# * https://wikipedia.org/wiki/List_of_neighborhoods_in_Atlanta,_Georgia
